# %%
# !pip install pandas_datareader

# %%
import pandas_datareader as web

# %%
from datetime import datetime

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
stockSymbols=['FB','AMzN','AAPL','NFLX','GOOG']

# %%
stock_start_date='2013-01-01'
stock_start_date
# Out:
# '2013-01-01'

# %%
today=datetime.today().strftime('%Y-%m-%d')

# %%
today
# Out:
# '2020-06-17'

# %%
numAssets=len(stockSymbols)
print('you have ' + str(numAssets)+ ' assets in your portfolio')
# Out:
# you have 5 assets in your portfolio

# %%
def getMyPortfolio(Stocks=stockSymbols,start=stock_start_date,end=today, col='Adj Close'):
    data=web.DataReader(Stocks,data_source='yahoo',start=start,end=end)[col]
    return data

# %%
my_stocks=getMyPortfolio(stockSymbols)
my_stocks
# Out:
# Symbols             FB         AMzN        AAPL        NFLX         GOOG
# Date
# 2012-12-31   26.620001   250.869995   66.398476   13.227143   352.369232
# 2013-01-02   28.000000   257.309998   68.502106   13.144286   360.274597
# 2013-01-03   27.770000   258.480011   67.637436   13.798572   360.483826
# 2013-01-04   28.760000   259.149994   65.753418   13.711429   367.607117
# 2013-01-07   29.420000   268.459991   65.366646   14.171429   366.003143
# ...                ...          ...         ...         ...          ...
# 2020-06-11  224.429993  2557.959961  335.899994  425.559998  1403.839966
# 2020-06-12  228.580002  2545.020020  338.799988  418.070007  1413.180054
# 2020-06-15  232.500000  2572.679932  342.989990  425.500000  1419.849976
# 2020-06-16  235.649994  2615.270020  352.079987  436.130005  1442.719971
# 2020-06-17  232.830002  2642.909912  353.660004  444.570587  1440.939941
#
# [1879 rows x 5 columns]

# %%
my_stocks=getMyPortfolio(stockSymbols)
my_stocks
# Out:
# Symbols             FB         AMzN        AAPL        NFLX         GOOG
# Date
# 2012-12-31   26.620001   250.869995   66.398476   13.227143   352.369232
# 2013-01-02   28.000000   257.309998   68.502106   13.144286   360.274597
# 2013-01-03   27.770000   258.480011   67.637436   13.798572   360.483826
# 2013-01-04   28.760000   259.149994   65.753418   13.711429   367.607117
# 2013-01-07   29.420000   268.459991   65.366646   14.171429   366.003143
# ...                ...          ...         ...         ...          ...
# 2020-06-11  224.429993  2557.959961  335.899994  425.559998  1403.839966
# 2020-06-12  228.580002  2545.020020  338.799988  418.070007  1413.180054
# 2020-06-15  232.500000  2572.679932  342.989990  425.500000  1419.849976
# 2020-06-16  235.649994  2615.270020  352.079987  436.130005  1442.719971
# 2020-06-17  232.949997  2646.000000  353.687988  445.359985  1439.550049
#
# [1879 rows x 5 columns]

# %%
def showgraph(Stocks=stockSymbols,start=stock_start_date,end=today, col='Adj Close'):
    title='portfolio'+col+'Price history'
    my_stocks=getMyPortfolio(stock=stocks,start=start,end=end,col=col)
    plt.figure(figsize=(12,6))
    for c in my_stocks.columns.values:
        plt.plot(my_stocks[c],label=c)

# %%
plt.title('title')
plt.xlabel('Date,fontsize=18')
plt.ylabel('col'+"price USD($)",fontsize=18)
plt.legend(my_stocks.columns.value,loc='upper left')
plt.show()
showgraph(stockSymbols)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-9a263e7bd2ee> in <module>
#       2 plt.xlabel('Date,fontsize=18')
#       3 plt.ylabel('col'+"price USD($)",fontsize=18)
# ----> 4 plt.legend(my_stocks.columns.value,loc='upper left')
#       5 plt.show()
#       6 showgraph(stockSymbols)
#
# AttributeError: 'Index' object has no attribute 'value'

# %%
daily_simple_returns=my_stocks.pct_change(1)
daily_simple_returns
# Out:
# Symbols           FB      AMzN      AAPL      NFLX      GOOG
# Date
# 2012-12-31       NaN       NaN       NaN       NaN       NaN
# 2013-01-02  0.051841  0.025671  0.031682 -0.006264  0.022435
# 2013-01-03 -0.008214  0.004547 -0.012623  0.049777  0.000581
# 2013-01-04  0.035650  0.002592 -0.027855 -0.006315  0.019760
# 2013-01-07  0.022949  0.035925 -0.005882  0.033549 -0.004363
# ...              ...       ...       ...       ...       ...
# 2020-06-11 -0.051958 -0.033802 -0.048010 -0.020530 -0.042303
# 2020-06-12  0.018491 -0.005059  0.008634 -0.017600  0.006653
# 2020-06-15  0.017149  0.010868  0.012367  0.017772  0.004720
# 2020-06-16  0.013548  0.016555  0.026502  0.024982  0.016107
# 2020-06-17 -0.011458  0.011750  0.004567  0.021163 -0.002197
#
# [1879 rows x 5 columns]

# %%
monthly_simple_returns=my_stocks.pct_change(1)
monthly_simple_returns
# Out:
# Symbols           FB      AMzN      AAPL      NFLX      GOOG
# Date
# 2012-12-31       NaN       NaN       NaN       NaN       NaN
# 2013-01-02  0.051841  0.025671  0.031682 -0.006264  0.022435
# 2013-01-03 -0.008214  0.004547 -0.012623  0.049777  0.000581
# 2013-01-04  0.035650  0.002592 -0.027855 -0.006315  0.019760
# 2013-01-07  0.022949  0.035925 -0.005882  0.033549 -0.004363
# ...              ...       ...       ...       ...       ...
# 2020-06-11 -0.051958 -0.033802 -0.048010 -0.020530 -0.042303
# 2020-06-12  0.018491 -0.005059  0.008634 -0.017600  0.006653
# 2020-06-15  0.017149  0.010868  0.012367  0.017772  0.004720
# 2020-06-16  0.013548  0.016555  0.026502  0.024982  0.016107
# 2020-06-17 -0.011458  0.011750  0.004567  0.021163 -0.002197
#
# [1879 rows x 5 columns]

# %%
daily_simple_returns.corr()
# Out:
# Symbols        FB      AMzN      AAPL      NFLX      GOOG
# Symbols
# FB       1.000000  0.503575  0.434578  0.341948  0.560890
# AMzN     0.503575  1.000000  0.427161  0.436899  0.603351
# AAPL     0.434578  0.427161  1.000000  0.249233  0.531189
# NFLX     0.341948  0.436899  0.249233  1.000000  0.413421
# GOOG     0.560890  0.603351  0.531189  0.413421  1.000000

# %%
daily_simple_returns.cov()
# Out:
# Symbols        FB      AMzN      AAPL      NFLX      GOOG
# Symbols
# FB       0.000462  0.000206  0.000163  0.000213  0.000193
# AMzN     0.000206  0.000363  0.000142  0.000242  0.000184
# AAPL     0.000163  0.000142  0.000304  0.000126  0.000148
# NFLX     0.000213  0.000242  0.000126  0.000842  0.000192
# GOOG     0.000193  0.000184  0.000148  0.000192  0.000257

# %%
print("th daily stock volatility")
daily_simple_returns.var()
# Out:
# th daily stock volatility
# Symbols
# FB      0.000462
# AMzN    0.000363
# AAPL    0.000304
# NFLX    0.000842
# GOOG    0.000257
# dtype: float64

# %%
daily_simple_returns.std()
# Out:
# Symbols
# FB      0.021484
# AMzN    0.019062
# AAPL    0.017440
# NFLX    0.029019
# GOOG    0.016026
# dtype: float64

# %%
mean=daily_simple_returns.mean()
mean
# Out:
# Symbols
# FB      0.001383
# AMzN    0.001436
# AAPL    0.001044
# NFLX    0.002280
# GOOG    0.000877
# dtype: float64

# %%
randomweights=np.array([0.1,0.4,0.3,0.2,0.1])
portfolio_simple_return=np.sum(mean*randomweights)

# %%
print("The daily expected portfolio return:"+str (portfolio_simple_return))
# Out:
# The daily expected portfolio return:0.0015695445246060595

# %%
daily_cum_return=(daily_simple_returns+1).cumprod()
daily_cum_return
# Out:
# Symbols           FB       AMzN      AAPL       NFLX      GOOG
# Date
# 2012-12-31       NaN        NaN       NaN        NaN       NaN
# 2013-01-02  1.051841   1.025671  1.031682   0.993736  1.022435
# 2013-01-03  1.043201   1.030335  1.018659   1.043201  1.023029
# 2013-01-04  1.080391   1.033005  0.990285   1.036613  1.043244
# 2013-01-07  1.105184   1.070116  0.984460   1.071390  1.038692
# ...              ...        ...       ...        ...       ...
# 2020-06-11  8.430878  10.196357  5.058851  32.173236  3.984003
# 2020-06-12  8.586777  10.144776  5.102527  31.606977  4.010509
# 2020-06-15  8.734034  10.255032  5.165630  32.168700  4.029438
# 2020-06-16  8.852366  10.424802  5.302531  32.972351  4.094342
# 2020-06-17  8.750939  10.547296  5.326749  33.670157  4.085345
#
# [1879 rows x 5 columns]
